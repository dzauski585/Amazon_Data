# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Kindle.Devices.ReadingSession.csv', parse_dates=True)
df.head()
# Out:
#         start_timestamp         end_timestamp        ASIN  \
# 0  2017-12-29T16:06:15Z  2017-12-29T16:17:23Z  B018ER7L5W
# 1  2018-03-20T18:14:13Z  2018-03-20T18:14:19Z  B001BANK2S
# 2  2017-12-23T20:03:08Z  2017-12-23T20:03:09Z  B018ER7L5W
# 3  2017-12-22T16:31:56Z  2017-12-22T16:44:25Z  B018ER7L5W
# 4  2018-06-27T00:08:56Z  2018-06-27T00:09:00Z  B001BANK2S
#
#   purchased_marketplace preferred_marketplace device_family  \
# 0                   NaN                    US           NaN
# 1                    US                    US           NaN
# 2                   NaN                    US           NaN
# 3                   NaN                    US           NaN
# 4                    US                    US           NaN
#
#                device_serial_number  device_software_version content_type  \
# 0  C47A706FC64E4BB2A357BA218FAF5913             1.174667e+09       E-Book
# 1  C47A706FC64E4BB2A357BA218FAF5913             1.175458e+09       E-Book
# ...

# %%
plt.figure(figsize =(10, 10))
sns.lineplot(x = df.start_timestamp, y = df.total_reading_millis)
# Out:
# <Axes: xlabel='start_timestamp', ylabel='total_reading_millis'>
