# %%
import pandas as pd
df = pd.read_csv('Retail.OrderHistory.1.csv')
df.head()
# Out:
#       Website             Order ID                Order Date  \
# 0  Amazon.com  114-1056778-2141031  2023-07-24T19:08:50.551Z
# 1  Amazon.com  114-0100671-4148275  2023-07-24T19:08:18.487Z
# 2  Amazon.com  114-8217841-9888269  2023-07-24T15:31:09.738Z
# 3  Amazon.com  112-4856348-9796227      2023-07-11T13:07:53Z
# 4  Amazon.com  112-4856348-9796227      2023-07-11T13:07:53Z
#
#   Purchase Order Number Currency  Unit Price  Unit Price Tax  Shipping Charge  \
# 0        Not Applicable      USD       29.45             0.0              0.0
# 1        Not Applicable      USD       79.99             0.0              0.0
# 2        Not Applicable      USD       79.99             0.0              0.0
# 3        Not Applicable      USD       34.99             0.0              0.0
# 4        Not Applicable      USD       99.99             0.0              0.0
#
#   Total Discounts  Total Owed  ... Shipment Status             Ship Date  \
# ...

# %%
df.shape
# Out:
# (1056, 27)

# %%
#Gets all columsn since df.head cuts off some of them
for col in df.columns:
        print(col)
# Out:
# Website
# Order ID
# Order Date
# Purchase Order Number
# Currency
# Unit Price
# Unit Price Tax
# Shipping Charge
# Total Discounts
# Total Owed
# Shipment Item Subtotal
# Shipment Item Subtotal Tax
# ASIN
# Product Condition
# Quantity
# Payment Instrument Type
# Order Status
# Shipment Status
# Ship Date
# Shipping Option
# Shipping Address
# Billing Address
# Carrier Name & Tracking Number
# Product Name
# Gift Message
# Gift Sender Name
# Gift Recipient Contact Details

# %%
df = df.fillna(0)
df.head()
# Out:
#       Website             Order ID                Order Date  \
# 0  Amazon.com  114-1056778-2141031  2023-07-24T19:08:50.551Z
# 1  Amazon.com  114-0100671-4148275  2023-07-24T19:08:18.487Z
# 2  Amazon.com  114-8217841-9888269  2023-07-24T15:31:09.738Z
# 3  Amazon.com  112-4856348-9796227      2023-07-11T13:07:53Z
# 4  Amazon.com  112-4856348-9796227      2023-07-11T13:07:53Z
#
#   Purchase Order Number Currency  Unit Price  Unit Price Tax  Shipping Charge  \
# 0        Not Applicable      USD       29.45             0.0              0.0
# 1        Not Applicable      USD       79.99             0.0              0.0
# 2        Not Applicable      USD       79.99             0.0              0.0
# 3        Not Applicable      USD       34.99             0.0              0.0
# 4        Not Applicable      USD       99.99             0.0              0.0
#
#   Total Discounts  Total Owed  ... Shipment Status             Ship Date  \
# ...

# %%
df["Total Owed"].sum()
#Total spent on amazon with non digital orders
# Out:
# 33674.880000000005

# %%
df["Total Owed"].mean()
# Out:
# 31.889090909090914

# %%
df["Total Owed"].min()
# Out:
# 0.0

# %%
df["Total Owed"].max()
# Out:
# 917.99

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='ISO8601') # format was used after reading the to_datetime docs and dealing with slightly inconsistant times
df.head()
# Out:
#       Website             Order ID                       Order Date  \
# 0  Amazon.com  114-1056778-2141031 2023-07-24 19:08:50.551000+00:00
# 1  Amazon.com  114-0100671-4148275 2023-07-24 19:08:18.487000+00:00
# 2  Amazon.com  114-8217841-9888269 2023-07-24 15:31:09.738000+00:00
# 3  Amazon.com  112-4856348-9796227        2023-07-11 13:07:53+00:00
# 4  Amazon.com  112-4856348-9796227        2023-07-11 13:07:53+00:00
#
#   Purchase Order Number Currency  Unit Price  Unit Price Tax  Shipping Charge  \
# 0        Not Applicable      USD       29.45             0.0              0.0
# 1        Not Applicable      USD       79.99             0.0              0.0
# 2        Not Applicable      USD       79.99             0.0              0.0
# 3        Not Applicable      USD       34.99             0.0              0.0
# 4        Not Applicable      USD       99.99             0.0              0.0
#
#   Total Discounts  Total Owed  ... Shipment Status             Ship Date  \
# ...

# %%
df.plot.bar(x='Order Date', y='Total Owed', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='Order Date'>

# %%
daily_orders = df.groupby('Order Date').sum()["Total Owed"]
daily_orders.head()
# Out:
# Order Date
# 2009-12-07 19:42:08+00:00    16.93
# 2010-01-12 17:00:49+00:00    40.33
# 2010-01-28 04:05:17+00:00    20.49
# 2010-02-01 21:21:27+00:00     7.55
# 2010-02-07 20:53:43+00:00     6.58
# Name: Total Owed, dtype: float64

# %%
tax = df['Shipment Item Subtotal Tax']

tax.dropna()
# Out:
# 0       Not Available
# 1       Not Available
# 2       Not Available
# 3                   0
# 4                   0
#             ...
# 1051                0
# 1052                0
# 1053             1.28
# 1054             2.66
# 1055                0
# Name: Shipment Item Subtotal Tax, Length: 1056, dtype: object

# %%
tax.head()
# Out:
# 0    Not Available
# 1    Not Available
# 2    Not Available
# 3                0
# 4                0
# Name: Shipment Item Subtotal Tax, dtype: object

# %%
daily_orders.plot.bar(figsize=(120,30),color='#61D199')
# Out:
# <Axes: xlabel='Order Date'>
